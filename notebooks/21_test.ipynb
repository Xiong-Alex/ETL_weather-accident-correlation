# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

sns.set_theme(style="whitegrid")

engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@postgres:5432/etl_db",
    pool_pre_ping=True
)

# %%
accidents_df = pd.read_sql(
    """
    SELECT
        start_time_utc::date AS date,
        COUNT(*)            AS accident_count,
        AVG(severity)       AS avg_severity
    FROM silver.us_accidents
    WHERE
        state = 'GA'
        AND start_time_utc >= '2022-01-01'
    GROUP BY start_time_utc::date
    ORDER BY date
    """,
    engine
)

accidents_df.head()
# Out:
#          date  accident_count  avg_severity
# 0  2022-01-01              81      2.271605
# 1  2022-01-02             128      2.226562
# 2  2022-01-03              98      2.295918
# 3  2022-01-04             118      2.245763
# 4  2022-01-05              62      2.338710

# %%
weather_df = pd.read_sql(
    """
    SELECT
        w.obs_date AS date,

        COALESCE(
            AVG(CASE WHEN w.element = 'TAVG' THEN w.value END),
            (
                AVG(CASE WHEN w.element = 'TMAX' THEN w.value END) +
                AVG(CASE WHEN w.element = 'TMIN' THEN w.value END)
            ) / 2
        ) AS avg_temp,

        SUM(CASE WHEN w.element = 'PRCP' THEN w.value END) AS total_precip,

        AVG(CASE WHEN w.element = 'AWND' THEN w.value END) AS avg_wind

    FROM silver.weather_daily w
    JOIN silver.stations s
      ON w.station_id = s.station_id
    WHERE s.state = 'GA'
    GROUP BY w.obs_date
    ORDER BY w.obs_date
    """,
    engine
)

weather_df.head()
# Out:
#          date   avg_temp  total_precip avg_wind
# 0  2015-01-01   6.348782          33.6     None
# 1  2015-01-02   9.243188         690.0     None
# 2  2015-01-03  13.078402        3524.7     None
# 3  2015-01-04  14.997030        9224.3     None
# 4  2015-01-05   9.413001        3659.8     None

# %%
df = accidents_df.merge(
    weather_df,
    on="date",
    how="left"
)

df.head()
# Out:
#          date  accident_count  avg_severity   avg_temp  total_precip avg_wind
# 0  2022-01-01              81      2.271605  20.726842         741.2     None
# 1  2022-01-02             128      2.226562  19.935571        5699.2     None
# 2  2022-01-03              98      2.295918   9.907700       10616.2     None
# 3  2022-01-04             118      2.245763   5.140445         112.1     None
# 4  2022-01-05              62      2.338710   7.560680          17.0     None

# %%
plt.figure()
sns.scatterplot(
    data=df,
    x="total_precip",
    y="accident_count"
)
plt.title("Georgia: Daily Accidents vs Precipitation")
plt.xlabel("Total Daily Precipitation")
plt.ylabel("Accident Count")
plt.show()

# %%
df["rainy_day"] = df["total_precip"].fillna(0) >= 2.5

plt.figure()
sns.scatterplot(
    data=df,
    x="avg_temp",
    y="avg_severity",
    hue="rainy_day",
    palette={True: "steelblue", False: "orange"},
    alpha=0.7
)
plt.title("Georgia: Severity vs Temperature (Rainy vs Dry Days)")
plt.xlabel("Average Daily Temperature (°C)")
plt.ylabel("Average Severity")
plt.legend(title="Rainy Day")
plt.show()

# %%
plt.figure()
sns.boxplot(
    data=df,
    x="rainy_day",
    y="avg_severity",
    hue="rainy_day",
    palette={True: "steelblue", False: "orange"},
    legend=False
)
plt.title("Georgia: Average Severity on Rainy vs Dry Days")
plt.xlabel("Rainy Day (≥ 2.5 mm)")
plt.ylabel("Average Daily Severity")
plt.show()

# %%
plt.figure()
sns.lineplot(
    data=df,
    x="date",
    y="accident_count"
)
plt.title("Georgia: Daily Accident Count Over Time")
plt.xlabel("Date")
plt.ylabel("Accident Count")
plt.show()

# %%
df["precip_bin"] = pd.cut(
    df["total_precip"].fillna(0),
    bins=[-0.01, 0.1, 1.0, 5.0, 20.0, float("inf")],
    labels=["Dry", "Drizzle", "Light", "Moderate", "Heavy"]
)

plt.figure()
sns.boxplot(
    data=df,
    x="precip_bin",
    y="accident_count"
)
plt.title("Georgia: Daily Accident Count by Precipitation Level")
plt.xlabel("Precipitation Level")
plt.ylabel("Accident Count")
plt.show()

# %%
df["is_weekend"] = pd.to_datetime(df["date"]).dt.dayofweek >= 5

plt.figure()
sns.boxplot(
    data=df,
    x="is_weekend",
    y="accident_count"
)
plt.title("Georgia: Accident Count on Weekdays vs Weekends")
plt.xlabel("Weekend")
plt.ylabel("Daily Accident Count")
plt.show()

# %%
df["temp_bin"] = pd.cut(
    df["avg_temp"],
    bins=[-10, 5, 15, 25, 35, 50],
    labels=["Very Cold", "Cold", "Mild", "Warm", "Hot"]
)

plt.figure()
sns.boxplot(
    data=df,
    x="temp_bin",
    y="accident_count",
    hue="rainy_day"
)
plt.title("Georgia: Accidents by Temperature and Rain")
plt.xlabel("Temperature Range (°C)")
plt.ylabel("Daily Accident Count")
plt.show()

# %%
df["month"] = pd.to_datetime(df["date"]).dt.month_name()

plt.figure()
sns.boxplot(
    data=df,
    x="month",
    y="accident_count"
)
plt.title("Georgia: Monthly Accident Distribution")
plt.xlabel("")
plt.ylabel("Daily Accident Count")
plt.show()

# %%
df = df.sort_values("date")
df["prev_rain"] = df["rainy_day"].shift(1)

plt.figure()
sns.boxplot(
    data=df,
    x="prev_rain",
    y="accident_count"
)
plt.title("Georgia: Accidents Following Rainy Days")
plt.xlabel("Previous Day Was Rainy")
plt.ylabel("Daily Accident Count")
plt.show()
