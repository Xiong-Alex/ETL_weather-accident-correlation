# %% [markdown]
# Will setup download via code later,
# for now manually download:
# https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents?resource=download
#
# and move into data/landing/accidents
